# %%
from langchain_core.messages import AIMessage

ai_msg = AIMessage(content="Message from AI")
ai_msg.text
# Out:
# 'Message from AI'

# %%
from langchain_core.messages import HumanMessage

human_msg = HumanMessage(content="Message from Human")
human_msg.text
# Out:
# 'Message from Human'

# %%
history = [ai_msg, human_msg]
for m in history:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Message from AI
# ================================ Human Message =================================
#
# Message from Human

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
history + [AIMessage(content="Other message from AI")]
# Out:
# [AIMessage(content='Message from AI', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Message from Human', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Other message from AI', additional_kwargs={}, response_metadata={})]
